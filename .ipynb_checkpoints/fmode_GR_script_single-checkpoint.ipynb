# %%
import time

# %%
# %%capture
# %run general_relativity/generalRelativity.py

# %%
# %%time
experiment = GeneralRelativity()
# experiment.read_data('/Users/utkarsh/PycharmProjects/fmodes/LCEHL_EOS_posterior_samples/eos_1.csv')
experiment.read_data('/Users/utkarsh/PycharmProjects/fmodes/2205.02081/SLY4.csv')
experiment.initial_conditions(k = -70)
experiment.tov(progress = False)
time.sleep(0.25)
experiment.update_initial_conditions()
experiment.tov(progress = False)
time.sleep(0.25)
experiment.update_initial_conditions()
experiment.tov(progress = True)
time.sleep(0.25)
experiment.print_params()
experiment.minimize_K0()
experiment.plot_loss()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/scipy/integrate/_ode.py:1011: UserWarning: vode: Excess work done on this call. (Perhaps wrong MF.)
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
#  56%|█████▌    | 11226/20000 [00:01<00:01, 7751.79it/s]
# Star has mass 1.729+0.000j Msun and radius 11.225km
# Interior Surface: 0.54518543+0.00000000j
# Exterior Surface: 0.54518543+0.00000000j
# nu0: (-1.3035977823968148+0j)
# Lamda: (0.6066293040737563-0j)
# Boundary Term: (5.754301123309632e+22-1.26967827496292e+18j)
# CPU times: user 43 s, sys: 477 ms, total: 43.5 s
# Wall time: 44.3 s

# %%
experiment.hw1, experiment.hw2, experiment.hw3 = [300, 100, 30]
experiment.optimize_fmode(hw=None, progress = True)
experiment.plot_loss_fmode()
experiment.optimize_fmode(hw=experiment.hw1, progress = True)
experiment.plot_loss_fmode()
experiment.optimize_fmode(hw=experiment.hw2, progress = True)
experiment.plot_loss_fmode()
experiment.optimize_fmode(hw=experiment.hw3, progress = True)
experiment.plot_loss_fmode()
# Out:
# 100%|██████████| 10/10 [06:54<00:00, 41.43s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/scipy/integrate/_ode.py:1011: UserWarning: vode: Excess work done on this call. (Perhaps wrong MF.)
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# 100%|██████████| 10/10 [06:51<00:00, 41.20s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/scipy/integrate/_ode.py:1011: UserWarning: vode: Excess work done on this call. (Perhaps wrong MF.)
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# 100%|██████████| 10/10 [07:50<00:00, 47.07s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/scipy/integrate/_ode.py:1011: UserWarning: vode: Excess work done on this call. (Perhaps wrong MF.)
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# 100%|██████████| 10/10 [08:01<00:00, 48.14s/it]

# %%
experiment.plot_fluid_perturbations()
