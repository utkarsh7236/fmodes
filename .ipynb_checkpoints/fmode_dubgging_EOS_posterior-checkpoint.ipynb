# %%
# %%capture
# %run cowling_approximation/fModes.py

# %%
fmodes1 = fmodes()
fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/LCEHL_EOS_posterior_samples/eos_1244.csv')
fmodes1.parallel_simulation(progress = True)
fmodes1.print_results()
fmodes1.plot_fmass()
fmodes1.plot_mass_radius()
# Out:
# 100%|██████████| 100/100 [04:35<00:00,  2.76s/it]
# M_max = 2.594169362336775
# R_max = 11.47501
# f_max = 27840.1029946834
#
# M_1.4 = 1.4306310516278096
# R_1.4 = 11.60901
# f_1.4 = 2287.1908644755918

# %%
fmodes1 = fmodes()
fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/LCEHL_EOS_posterior_samples/eos_1259.csv')
fmodes1.parallel_simulation(progress = True)
fmodes1.print_results()
fmodes1.plot_fmass()
fmodes1.plot_mass_radius()
# Out:
# 100%|██████████| 100/100 [04:42<00:00,  2.82s/it]
# M_max = 2.0978660329752916
# R_max = 10.17001
# f_max = 2900.0963839137694
#
# M_1.4 = 1.3979276996826362
# R_1.4 = 12.30801
# f_1.4 = 2301.891058851036
