# %%
from scipy.integrate import ode
from scipy.interpolate import interp1d
import pandas as pd
from astropy import units as u
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm_notebook as tqdm
import time
from scipy.optimize import minimize, approx_fprime

# %%
import matplotlib as mpl
# mpl.rcParams['figure.dpi'] = 1000
mpl.rcParams['legend.frameon'] = False
mpl.rcParams['figure.autolayout'] = True 
# mpl.rcParams['axes.spines.right'] = False
# mpl.rcParams['axes.spines.top'] = False


# plt.rcParams.update({
#     "text.usetex": True,
#     "font.family": "sans-serif",
#     "font.sans-serif": ["Helvetica"]})

# plt.rcParams.update({
#     "text.usetex": True,
#     "font.family": "serif",
#     "font.serif": ["Palatino"],
# })

def utkarshGrid():
    plt.minorticks_on()
    plt.grid(color='grey',
             which='minor',
             linestyle=":",
             linewidth='0.1',
             )
    plt.grid(color='black',
             which='major',
             linestyle=":",
             linewidth='0.1',
             )

# %%
G = 6.67259e-8 # dyne cm2 g-2
c = 2.998e10 # cms-1
n_den = 2.3e14
km2cm = 1e5
msun = 1.989e33

path = "eos_data/nl3cr.csv"
# G = c = 1

# DIMENSIONS CHECKED
def lamba_metric(M, R):
    # Removed factor of 2 since the paper didnt implement it. 
    return -np.log((1-2*G*M/(c**2*R)))

def df_to_ep(df):
    e_den = df.energy_densityc2
    e_den_normed = e_den#/n_den
    p = df.pressurec2
    e_den_normed = e_den_normed*((2.998e10)**2)
    pressure = p*((2.998e10)**2)
    return e_den_normed.to_numpy(), pressure.to_numpy()

def get_ep(e, p):
    f_e_smooth = interp1d(p, e, fill_value=(0, 0), 
                          kind = "linear", bounds_error=False)
    return f_e_smooth

# %%
# Working in manual cgs units here. 

# DIMENSIONS CHECKED
def _dMdr(r, e):
    return 4 * np.pi * r**2 * (e/(c**2))

# DIMENSIONS CHECKED
def _b(r, M):
    return (G*M)/((c**2)*r)

# DIMENSIONS CHECKED
def _dvdr(r, Q, lamda):
    return (2/r) * np.exp(lamda) * Q

# DIMENSIONS CHECKED
def _Q(r, P, M):
    frac = (4 * np.pi * G * (r**2)*P)/(c**4)
    return _b(r, M) + frac

# DIMENSIONS CHECKED
def _dPdr(r, P, M, e):    
    # dphidr (From other cowling: arXiv1012.4042)
    num = (M+4*np.pi*(r**3)*P/(c**2))
    dem = r * (r-2*G*M/(c**2))
    return -1 * (e+P) * G/(c**2) * num/dem

# %%
# Working in manual cgs units here. 

# DIMENSIONS CHECKED
def _dWdlnr(r, W, U, Q, lamda, l, omega, v, c_ad2):
    term1 = -1*(l+1)*(W-l*np.exp(v+lamda/2)*U)
    frac1 = -1 * (np.exp(lamda/2) * (omega*r)**2)/(c_ad2)
    frac2 = (np.exp(lamda/2)*Q*W*(c**2))/((omega*r)**2)
    term2 = frac1 * (U - frac2)
    return term1 + term2

# DIMENSIONS CHECKED
def _dUdlnr(r, W, U, lamda, l, v):
    return np.exp(lamda/2 - v) * (W - l*(np.exp(v-lamda/2))*U)

# %%
from scipy.misc import derivative 

def coupledTOV(r, VEC, init_params):
    P, M, v, W, U = VEC
    EOS, l, omega, dedp_EQ = init_params
    

    lamda = lamba_metric(M, r)
    Q = _Q(r, P, M)
    e = EOS(P)
    
 # ++++ DIFFERENT METHODS FOR DEDP ++++   
    
    dedp = dedp_EQ(P)
    
#     dedp = derivative(EOS, P, dx = 1e30, n = 1)
    
#     eps = 1e5
#     p_eval = np.linspace(P/eps, P*eps, 5)
#     eps = 1e-1
#     p_eval = np.logspace(np.floor(np.log10(P/eps)), np.ceil(np.log10(P*eps)), 10)
#     e_eval = EOS(p_eval)
#     dedp = np.mean(np.gradient(e_eval, p_eval, edge_order=2))
    
#     eps = 1e5
#     p_eval = np.linspace(P/eps, P*eps, 10)
#     e_eval = EOS(p_eval)
#     dedp = approx_fprime(np.mean(p_eval), EOS, epsilon = eps)    


#  +++++++++++++++++++++++++++++++++++++
    drhodp = dedp / (c**2)
    c_ad2 = 1/drhodp # has units of (m/s)^2
    
    dPdr = _dPdr(r, P, M, e)
    dMdr = _dMdr(r, e)
    dvdr = _dvdr(r, Q, lamda)
    

    
    # Not sure if taking the log is the correct way to go about it. 
    dWdlnr = _dWdlnr(r, W, U, Q, lamda, l, omega, v, c_ad2)
    dUdlnr = _dUdlnr(r, W, U, lamda, l, v)
    
    dWdr = dWdlnr * 1/r
    dUdr = dUdlnr * 1/r
    
    ret = [dPdr, dMdr, dvdr, dWdr, dUdr]
    return ret

# %%
df = pd.read_csv(path)
e, p = df_to_ep(df)
minimum_pressure = min(p)
EOS = get_ep(e, p)
plt.scatter(p, e, s = 1, label = "EOS")

K = 2.1e-9

def f(p, gamma = 3/2, K = K):
    return K*(c**2)*p**(1/gamma)

def polytrope(P, gamma = 3/2, K = K):
    return K*(c**2) * (1/gamma) * P ** ((1/gamma) - 1)

plt.scatter(p, f(p), s = 1, label = "polytrope")
plt.legend()
# plt.axvline(x=min(p))
plt.figure()
dedp = np.zeros(len(p))
dedp2 = np.zeros(len(p))
dedp3 = np.zeros(len(p))

# def dedp_arr(p, EOS):
#     x = np.logspace(np.floor(np.log10(min(p))), 
#                     np.ceil(np.log10(max(p))), 
#                     int(1e6), endpoint = True)
# #     x = np.linspace(min(p), max(p), int(1e7))
#     y = EOS(x)
#     dydx = np.diff(y)/np.diff(x)
#     return x, dydx

# def get_dedp(dedp, p):
#     dedp_EQ = interp1d(p[:-1], dedp, fill_value="extrapolate")
#     return dedp_EQ

def dedp_arr(p, EOS):
    x = p
    return x, np.gradient(EOS(x), x)

def get_dedp(dedp, p):
    dedp_EQ = interp1d(p, dedp, fill_value="extrapolate")
#     return dedp_EQ
    return polytrope

from scipy.misc import derivative

for i in tqdm(range(len(p))):
    
    # THIS CHOICE WAS NON-TRIVIAL: SCALE WITH ORDERS OF MAGNITUDE
    P = p[i]
#     log_eps = 1
#     order_P = np.floor(np.log10(P))
#     min_ind = max(np.log10(min(p)), order_P - log_eps)
#     max_ind = min(np.log10(max(p)), order_P + log_eps)
#     p_eval = np.logspace(min_ind, max_ind, 100)
#     e_eval = EOS(p_eval)
    eps = 1e-1
#     p_eval = np.linspace(P/eps, P*eps, 10)
    p_eval = np.logspace(np.floor(np.log10(P/eps)), np.ceil(np.log10(P*eps)), 10)
    e_eval = EOS(p_eval)
    dedp[i] = np.mean(np.gradient(e_eval, p_eval, edge_order=2))
    dedp2[i] = approx_fprime(np.mean(p_eval), EOS, epsilon = eps)
    dedp3[i] = derivative(EOS, P, dx = 1e30, n = 1)

    
# plt.plot(p, dedp, linewidth = 3)
# plt.plot(p, dedp2)
# x, dydx = dedp_arr(p, EOS)
# dedp_EQ = get_dedp(dydx, x)
# plt.plot(p, dedp_EQ(p))
plt.plot(p, polytrope(p))
# plt.plot(p, dedp3)
# plt.xlim(0.1e36, 3e36)
# plt.ylim(0, 1)
plt.ylabel("1/cs^2 (units of 1/c^2)")
plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1349.0), HTML(value='')))

# %%
def tov(ep, init_VEC, r_i, p_min, omega, dedp_EQ, progress = False, 
        l=2, n_iter_max = 20000):
    
    init_params = [ep, l, omega, dedp_EQ]

#     r = ode(lambda r, VEC: coupledTOV(r, VEC, init_params)).set_integrator('LSODA')
    r = ode(lambda r, VEC: coupledTOV(r, VEC, init_params)).set_integrator('VODE')
    r.set_initial_value(init_VEC, r_i)

    results = []
    r_list = []

    i = 0
    r_max = 20 * km2cm
    max_iter = n_iter_max

    dr_init = r_max/max_iter
    dr_compute = 100000
    
    if progress:
        pbar = tqdm(total=max_iter)

    while r.successful() and (r.y[0] >= p_min):
        i+=1

        dr = min(dr_init, dr_compute)
#         print(dr)

        integral = r.integrate(r.t+dr)

        if progress:
            pbar.update(1)
        
        if i > max_iter:
            print("[STATUS] max_iter reached")
            break
            
        if (r.y[0] < p_min):
            break
            
        if not r.successful():
            break
        
        results.append(integral)
        r_list.append(r.t+dr_init)
        
    if progress:
        pbar.close()
    
#     print(r.successful(),(r.y[0] >= p_min)) # Used to find out which condition breaks 1st.
    
    results = np.array(results, dtype = float)
    p, m, v, w, u = results.T
    r = np.array(r_list)
    return p, m, r, v, w, u

# %%
# Load EOS
df = pd.read_csv(path)
e, p = df_to_ep(df)
EOS = get_ep(e, p)

# Initial Conditions
km2cm = 1e5
r_i = 1
p0 = p[-2]
e0 = EOS(p0)
p_c = p0 - 2 * np.pi * (G/(c**4)) * r_i**2 * (p0 + e0) * (3*p0 + e0)/3
e_c = e0
m0 = e_c/(c**2) * 4/3 * np.pi * r_i**3


omega = 2e3*(2*np.pi) #Arbitrary guess
l=2

v0 = -1 # Two step integration optimization: similar to phi previously.

W0 = 1
U0 = W0/(l * np.exp(v0))

p_smooth, dedp = dedp_arr(p, EOS)
dedp_EQ = get_dedp(dedp, p_smooth)

init_VEC = [p_c, m0, v0, W0, U0]
p_min = min(p) 


# Integrate
p, m, r_arr, v, w, u = tov(EOS, init_VEC, r_i, p_min, 
                           omega, dedp_EQ, progress = True, l = l, 
                           n_iter_max = 2000)

max_idx = np.argmax(m)
m_R = m.max() # In units of msun
r_R = r_arr[max_idx] # In units of km
p_R = p[max_idx] #cgs
ec_R = EOS(p_R) #cgs
u_R = u[max_idx] #cgs
v_R = v[max_idx]
w_R = w[max_idx]

schild = (1-2*G*m_R/(c**2*r_R))
interior = np.exp(v_R)

# DIMENSIONED CHECKED
def boundary_wu(r_R, m_R, omega, w_R, u_R):
    frac1 = (omega**2 * r_R ** 3)/(G*m_R)
    return frac1 * np.sqrt(1-(2*G*m_R)/(r_R * (c**2))) - w_R/u_R

print("== First Integration == ")
print(f"Star has mass {m_R/msun:.1f} Msun and radius {r_R/km2cm:.1f}km")
print(f"Interior Surface: {interior:.4f}")
print(f"Exterior Surface: {schild:.4f}")
print(f"v0 Round 1: {v0}")
print(f"Lamda Round 1: {lamba_metric(m_R, r_R)}")
print(f"Boundary Term: {boundary_wu(r_R, m_R, omega, w_R, u_R)}")

# Computer new v0
v_ext = np.log(schild) #At surface
v_int = v_R #At surface
delta_v = v_int - v_ext
v0 =  v0 - delta_v

init_VEC = [p_c, m0, v0, W0, U0]
time.sleep(0.2)

p, m, r_arr, v, w, u = tov(EOS, init_VEC, r_i, p_min, omega,
                           dedp_EQ,
                           progress = True, l = l)

max_idx = np.argmax(m)
m_R = m.max() # In units of msun
r_R = r_arr[max_idx] # In units of km
p_R = p[max_idx] #cgs
ec_R = EOS(p_R) #cgs
u_R = u[max_idx] #cgs
v_R = v[max_idx]
w_R = w[max_idx]

schild = (1-2*G*m_R/(c**2*r_R))
interior = np.exp(v_R)

print("== Corrected Integration == ")
print(f"Star has mass {m_R/msun:.1f} Msun and radius {r_R/km2cm:.1f}km")
print(f"Interior Surface: {interior:.4f}")
print(f"Exterior Surface: {schild:.4f}")
print(f"v0 Round 1: {v0}")
print(f"Lamda Round 1: {lamba_metric(m_R, r_R)}")
print(f"Boundary Term: {boundary_wu(r_R, m_R, omega, w_R, u_R)}")
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/scipy/integrate/_ode.py:1011: UserWarning: vode: Excess work done on this call. (Perhaps wrong MF.)
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# == First Integration ==
# Star has mass 2.5 Msun and radius 11.6km
# Interior Surface: 4.9830
# Exterior Surface: 0.3582
# v0 Round 1: -1
# Lamda Round 1: 1.0265298678161756
# Boundary Term: -18685.576979025176
# HBox(children=(FloatProgress(value=0.0, max=20000.0), HTML(value='')))
# == Corrected Integration ==
# Star has mass 2.5 Msun and radius 11.5km
# Interior Surface: 0.3584
# Exterior Surface: 0.3579
# v0 Round 1: -3.6325587262174386
# Lamda Round 1: 1.0274602808561013
# Boundary Term: -5693.662741437805

# %%
print(f"{p_min:.2e}")
p # Notice that the surface pressure is well above lower limit.
# Out:
# 8.14e+11
# array([2.98708453e+36, 2.98708405e+36, 2.98708324e+36, ...,
#        6.82209712e+23, 2.09091607e+23, 2.44778446e+22])

# %%
r_arr = r_arr/km2cm

plt.figure()
plt.plot(r_arr, p/p_c)
plt.xlabel("r")
plt.ylabel("P/Pc")

plt.figure()
plt.plot(r_arr, m/msun)
plt.xlabel("r ")
plt.ylabel("M/Msun")
plt.show()

plt.figure()
plt.plot(r_arr, v)
plt.xlabel("r ")
plt.ylabel("v")
plt.show()

clip = -1

plt.figure()
plt.plot(r_arr[:clip], w[:clip])
plt.xlabel("r ")
plt.ylabel("w")
plt.show()

plt.figure()
plt.plot(r_arr[:clip], u[:clip])
plt.xlabel("r ")
plt.ylabel("u")
plt.show()

# %%
# Delete when shifting over to python
old_backend = mpl.get_backend() 
# %matplotlib notebook 
# ====================================================================================
fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()
fig.show()
fig.canvas.draw()
plt.xlabel("f-mode (Hz)")
plt.ylabel("log boundary value")

def minimize_boundary(params, p = p, EOS = EOS):
    # Repeat integration
     
    omega = params

    # Integrate
    p, m, r_arr, phi, w, v = p, m, r_arr, v, w, u = tov(EOS, init_VEC, r_i, p_min, omega, dedp_EQ, l = l)
    
    max_idx = np.argmax(m)
    m_R = m.max() # In units of msun
    r_R = r_arr[max_idx] # In units of km
    p_R = p[max_idx] #cgs
    ec_R = EOS(p_R) #cgs
    u_R = u[max_idx] #cgs
    v_R = v[max_idx]
    w_R = w[max_idx]
    
    loss = np.log10(abs(boundary_wu(r_R, m_R, omega, w_R, u_R)))
    ax.scatter(omega/(2*np.pi), loss, color = "dodgerblue", marker = "x")
    fig.canvas.draw()
    return loss

omega_guess = 2e3*(2*np.pi)
init_guess = [omega_guess]
res = minimize(minimize_boundary, x0 = init_guess, method='Nelder-Mead', 
               options = {"disp": True, "maxiter":15},
               tol = 1)

mpl.use(old_backend) # Delete when shifting over to python
display(res)
omg = res.x[0]
f = omg/(2*np.pi)
print(f"omega: {omg:.0f}")
print(f"fmode: {f:.2f} Hz")
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/scipy/integrate/_ode.py:1011: UserWarning: vode: Excess work done on this call. (Perhaps wrong MF.)
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# Optimization terminated successfully.
#          Current function value: 3.748763
#          Iterations: 13
#          Function evaluations: 30
#  final_simplex: (array([[12645.52402301],
#        [12646.13761533]]), array([3.74876303, 3.74922132]))
#            fun: 3.7487630298948194
#        message: 'Optimization terminated successfully.'
#           nfev: 30
#            nit: 13
#         status: 0
#        success: True
#              x: array([12645.52402301])
# omega: 12646
# fmode: 2012.60 Hz

# %%
# p, m, r_arr, v, w, u = tov(EOS, init_VEC, r_i, p_min, omg, dedp_EQ, progress = True, l = l)

# max_idx = np.argmax(m)
# m_R = m.max() # In units of msun
# r_R = r_arr[max_idx] # In units of km
# p_R = p[max_idx] #cgs
# ec_R = EOS(p_R) #cgs
# u_R = u[max_idx] #cgs
# v_R = v[max_idx]
# w_R = w[max_idx]

# schild = (1-2*G*m_R/(c**2*r_R))
# interior = np.exp(v_R)

# print("== Corrected Integration == ")
# print(f"Star has mass {m_R/msun:.1f} Msun and radius {r_R/km2cm:.1f}km")
# print(f"Interior Surface: {interior:.4f}")
# print(f"Exterior Surface: {schild:.4f}")
# print(f"v0 Round 1: {v0}")
# print(f"Lamda Round 1: {lamba_metric(m_R, r_R)}")
# print(f"Boundary Term: {boundary_wu(r_R, m_R, omega, w_R, u_R)}")
