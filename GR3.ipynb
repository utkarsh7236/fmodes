# %%
from scipy.integrate import ode
from scipy.interpolate import interp1d
import pandas as pd
from astropy import units as u
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from tqdm.notebook import tqdm_notebook as tqdm
import time
from scipy.optimize import minimize, approx_fprime, minimize_scalar

# %%
import matplotlib as mpl
mpl.rcParams['legend.frameon'] = False
mpl.rcParams['figure.autolayout'] = True 
def utkarshGrid():
    plt.minorticks_on()
    plt.grid(color='grey',
             which='minor',
             linestyle=":",
             linewidth='0.1',
             )
    plt.grid(color='black',
             which='major',
             linestyle=":",
             linewidth='0.1',
             )

# %%
np.set_printoptions(precision=2)

# %%
G = 6.67259e-8 # dyne cm2 g-2
c = 2.99792458e10 # cms-1
n_den = 2.3e14
km2cm = 1e5
msun = 1.98847e33

def lamba_metric(M, R):
    return -np.log((1-2*G*M/(c**2*R)))

def df_to_ep(df):
    e_den = df.energy_densityc2
    p_arr = df.pressurec2
    p = p_arr[p_arr > 1e8]
    e_den = e_den[p_arr > 1e8]
    e_den = e_den*((2.99792458e10)**2)
    pressure = p*((2.99792458e10)**2)
    return e_den.to_numpy(), pressure.to_numpy()
def get_ep(e, p):
    f_e_smooth = interp1d(p, e, fill_value= "extrapolate", kind = "cubic")
    return f_e_smooth
def get_pe(p, e):
    f_e_smooth = interp1d(e, p, fill_value=(0, 0), kind = "cubic", bounds_error=True)
    return f_e_smooth


path = "2205.02081/SLY4.csv"
df = pd.read_csv(path)
e_arr, p_arr = df_to_ep(df)
e, p = df_to_ep(df)
p_max = max(p)
p_min = max(1*(c**2), min(p)) 
EOS = get_ep(e, p)

# %%
def _dMdr(r, e):
    return 4 * np.pi * r**2 * (e/(c**2))
def _b(r, M):
    return (G*M)/((c**2)*r)
def _dnudr(r, Q, lamda):
    return (2/r) * np.exp(lamda) * Q
def _Q(r, P, M):
    frac = (4 * np.pi * G * (r**2)*P)/(c**4)
    return _b(r, M) + frac
def _dPdr(r, P, M, e):    
    num = (M+4*np.pi*(r**3)*P/(c**2))
    dem = r * (r-2*G*M/(c**2))
    return -1 * (e+P) * G/(c**2) * num/dem
def dedP_helper(p, e):
    return np.gradient(e, p), e
def dedP(p, e):
    dedp_helper, e_arr = dedP_helper(p, e)
    return interp1d(e_arr, dedp_helper, fill_value="extrapolate", kind = "cubic")
def drhodP(e, dedp = dedP(p, e)):
    return (c**-2) * dedp(e)

# %%
# DIMENSIONS CHECKED
def _H0(r, nu, X, nl, Q, omega, lamda, H1, b, K):
    omgr2_c2 = ((omega * r)**2)/(c**2)
    factor = (2*b + nl + Q) ** (-1)
    term1 = 8 * np.pi * (r**2) * np.exp(-nu/2) * X * (G/(c**4))
    term2 = - H1 * (Q*(nl+1) - omgr2_c2 * np.exp(-nu-lamda))
    term3 = K * (nl - omgr2_c2*np.exp(-nu)-Q*(np.exp(lamda)*Q-1))
    return factor * (term1 + term2 + term3)

# DIMENSIONS CHECKED
def _V(r, X, e, p, Q, nu, lamda, W, H0, omega):
    factor = np.exp(nu/2) * (c**2)/(omega**2)
    term1 = X/(e+p)
    term2 = -Q/(r**2) * W * np.exp((nu+lamda)/2)
    term3 = -np.exp(nu/2)*H0/2
    return factor * (term1 + term2 + term3)

# %%
## arXiv 2205.02081 ##
# DIMENSIONS CHECKED
def _dH1dr(r, l, b, lamda, p, e, H1, H0, K, V):
    G_c4 = G/(c**4)
    term1 = -H1*(l + 1 + 2*b*np.exp(lamda) + G_c4 * 4*np.pi*(r**2)*np.exp(lamda)*(p-e))
    term2 = np.exp(lamda) * (H0 + K - G_c4*16*np.pi*(e+p)*V)
    return (1/r) * (term1 + term2)

# DIMENSIONS CHECKED
def _dKdr(r, H0, nl, H1, lamda, Q, l, K, e, p, W):
    term1 = H0
    term2 = (nl+1)*H1
    term3 = (np.exp(lamda)*Q-l-1)*K
    term4 = -8*np.pi*(e+p)*np.exp(lamda/2)*W*G/(c**4)
    return (1/r) * (term1 + term2 + term3 + term4)

# DIMENSIONS CHECKED
def _dWdR(r, W, l, lamda, V, e, p, X, cad2_inv, H0, K, nu):
    term1 = -(l+1)*(W+l*np.exp(lamda/2)*V)
    term2_fac = (r**2 * np.exp(lamda/2))
    term2_1 = (np.exp(-nu/2)*X*(c**2) * cad2_inv)/(e+p)
    term2_2 = H0/2
    term2_3 = K
    term2 = term2_fac * (term2_1 + term2_2 + term2_3)
    return (1/r) * (term1 + term2)

# DIMENSIONS CHECKED 2205.02081
def _dXdr(r, l, X, e, p, nu, lamda, Q, H0, omega, nl, H1, K, V, W, derivative_term):
    omgr2_c2 = ((omega * r)**2)/(c**2)
    G_c4 = G/(c**4)
    term1 = -l*X
    term2_fac = (e+p)*np.exp(nu/2)/2
    term2_1 = (1-np.exp(lamda)*Q)*H0
    term2_2 = H1 * (omgr2_c2*np.exp(-nu) + nl + 1)
    term2_3 = K * (3*np.exp(lamda)*Q - 1)
    term2_4 = -4 * (nl + 1) * np.exp(lamda) * Q * V/(r**2)
    term2_5_fac = -2*W
    term2_5_1 = np.exp(lamda/2 - nu)*(omega**2)/(c**2)  
    term2_5_2 = G_c4 * 4 * np.pi * (e+p) * np.exp(lamda/2)
    term2_5_3 = -(r**2) * derivative_term
    term2_5 =  term2_5_fac * (term2_5_1 + term2_5_2 + term2_5_3)
    term2 = term2_fac * (term2_1 + term2_2 + term2_3 + term2_4 + term2_5)
    return (1/r) * (term1 + term2)

# %%
def derivative_term(r, dMdr, dPdr, m, P):
    pi = np.pi
    exp = np.exp
    sqrt = np.sqrt
    return G*(G*(dMdr*r - m)*(4*pi*P*r**3 + c**2*m) - 6*c**2*r*((-2*G*m + c**2*r)/(c**2*r))**(3/2)*(4*pi*P*r**3 + c**2*m) + 2*c**2*r*((-2*G*m + c**2*r)/(c**2*r))**(3/2)*(c**2*dMdr*r - c**2*m + 4*pi*r**3*(2*P + dPdr*r)))*exp(1/(2*sqrt((-2*G*m + c**2*r)/(c**2*r))))/(2*c**6*r**6*((-2*G*m + c**2*r)/(c**2*r))**(3/2))

# %%
def coupledTOV(r, VEC, init_params):
    P, M, nu, H1, K, W, X = VEC
    EOS, l, omega, p_min, p_max, nl = init_params
    if P <= p_min: 
        return None
    if P >= p_max:
        return None
    if 2*_b(r, M) >= 1:
        return None
    b = _b(r, M)
    lamda = np.log(1/(1-2*b))
    Q = _Q(r, P, M)
    e = EOS(P) 
    cad2_inv = drhodP(e)
    
    dPdr = _dPdr(r, P, M, e)
    dMdr = _dMdr(r, e)
    
    derv_term = derivative_term(r, dMdr, dPdr, M, P)
    
    dnudr = _dnudr(r, Q, lamda)
    H0 = _H0(r, nu, X, nl, Q, omega, lamda, H1, b, K)
    V = _V(r, X, e, P, Q, nu, lamda, W, H0, omega)

    # arXiv 2205.02081
    dH1dr = _dH1dr(r, l, b, lamda, P, e, H1, H0, K, V)
    dKdr = _dKdr(r, H0, nl, H1, lamda, Q, l, K, e, P, W)
    dWdr = _dWdR(r, W, l, lamda, V, e, P, X, cad2_inv, H0, K, nu)
    dXdr = _dXdr(r, l, X, e, P, nu, lamda, Q, H0, omega, nl, H1, K, V, W, derv_term)
    
    ret = [dPdr, dMdr, dnudr, dH1dr, dKdr, dWdr, dXdr]
    return ret

# %%
def tov(EOS, init_VEC, r_i, p_min,p_max, omega,nl, progress = False, 
        l=2, n_iter_max = 20000):
    init_params = [EOS, l, omega, p_min, p_max, nl]
    r = ode(lambda r, VEC: coupledTOV(r, VEC, init_params)).set_integrator('VODE')
    r.set_initial_value(init_VEC, r_i)
    results = []
    r_list = []
    i = 0
    r_max = 20 * km2cm
    max_iter = n_iter_max
    dr = r_max/max_iter
    if progress:
        pbar = tqdm(total=max_iter)
    while r.successful() and (r.y[0] >= p_min):
        i+=1
        integral = r.integrate(r.t+dr)
#         print(r.successful())
        if progress:
            pbar.update(1)
        if i > max_iter:
            print("[STATUS] max_iter reached")
            break
        if (r.y[0] < p_min):
            break
        if not r.successful():
            break
        results.append(integral)
        r_list.append(r.t+dr)
    if progress:
        pbar.close()
    
#     print("Integration, Pressure: ", r.successful(), (r.y[0] >= p_min))
    
    results = np.array(results, dtype = float)
    p, m, nu, h1, k, w, x = results.T
    r = np.array(r_list)
    return p, m, r, nu, h1, k, w, x

# %%
def initial_conditions(EOS, e, p, k, km2cm = 1e5, r_i = 1, K0 = None):
    p0 = p[k]
    e0 = EOS(p0)
    p_c = p0 - 2 * np.pi * (G/(c**4)) * r_i**2 * (p0 + e0) * (3*p0 + e0)/3
    e_c = EOS(p_c)
    m0 = e_c/(c**2) * 4/3 * np.pi * r_i**3
    omega = 2e3*(2*np.pi) #Arbitrary guess
    l=2 
    nl = (l-1)*(l+2)/2
    nu0 = -1 
    Q0 = _Q(r_i, p_c, m0)
    b0 = _b(r_i, m0)
    W0 = 1

    if K0 == None:
        K0 = -0.5 * (e_c + p_c) * (G/(c**4))
    
    # DIMENSIONS CHECKED
    X0_factor = (e_c + p_c) * np.exp(nu0/2)
    X0_term1 = 4 * np.pi/3 * (e_c + 3*p_c) * W0 * G/(c**4)
    X0_term2 = -(omega**2)/l * np.exp(-nu0) * W0  /(c**2)
    X0_term3 = K0/2
    X0 = X0_factor * (X0_term1 + X0_term2 + X0_term3)
    H00 = K0
    H10 = (l*K0 + 8*np.pi*(G/(c**4))*(e_c+p_c)*W0)/((nl+1))
    
    init_VEC = [p_c, m0, nu0, H10, K0, W0, X0]
    p_max = max(p)
    p_min = max(c**2, min(p)) 
    print("Initial: ", init_VEC)
    return p_c, e_c, m0, omega, l, nl, nu0, Q0, b0, W0, K0, X0, H00, H10, init_VEC, \
    p_max, p_min, r_i

# %%
def surface_conditions(p, m, r_arr, nu, h1, k, w, x):
    max_idx = np.argmax(m) - 1
    m_R = m.max() # In units of msun
    r_R = r_arr[max_idx] # In units of km
    p_R = p[max_idx] #cgs
    ec_R = EOS(p_R) #cgs
    nu_R = nu[max_idx]
    h1_R = h1[max_idx]
    k_R = k[max_idx]
    w_R = w[max_idx]
    x_R = x[max_idx]
    schild = (1-2*G*m_R/(c**2*r_R))
    interior = np.exp(nu_R)
    return max_idx, m_R, r_R, p_R, ec_R, nu_R, h1_R, k_R, w_R, x_R, schild, interior

def print_params(p, m, r_arr, nu, h1, k, w, x):
    max_idx, m_R, r_R, p_R, ec_R, nu_R, h1_R, k_R, w_R, x_R, schild, \
    interior = surface_conditions(p, m, r_arr, nu, h1, k, w, x)
    print(f"Star has mass {m_R/msun:.3f} Msun and radius {r_R/km2cm:.3f}km")
    print(f"Interior Surface: {interior:.8f}")
    print(f"Exterior Surface: {schild:.8f}")
    print(f"v0: {nu0}")
    print(f"Lamda: {lamba_metric(m_R, r_R)}")
    print(f"Boundary Term: {x_R}")
    return None

# %%
p_c, e_c, m0, omega, l, nl, nu0, Q0, b0, W0, K0, X0, H00, H10, init_VEC, \
p_max, p_min, r_i = initial_conditions(EOS, e_arr, p_arr, -91)

# p_c, e_c, m0, omega, l, nl, nu0, Q0, b0, W0, K0, X0, H00, H10, init_VEC, \
# p_max, p_min, r_i = initial_conditions(EOS, e, p, -27)

p, m, r_arr, nu, h1, k, w, x = tov(EOS, init_VEC, r_i, p_min,p_max, 
                           omega, nl, progress = True, l = l)

max_idx, m_R, r_R, p_R, ec_R, nu_R, h1_R, k_R, w_R, x_R, schild, \
interior = surface_conditions(p, m, r_arr, nu, h1, k, w, x)

print("== First Integration == ")
print_params(p, m, r_arr, nu, h1, k, w, x)

# Update init_VEC
nu_ext = -lamba_metric(m_R, r_R)
nu_int = nu_R #At surface
delta_nu = nu_int - nu_ext
nu0 =  nu0 - delta_nu

init_VEC = [p_c, m0, nu0, H10, K0, W0, X0]
time.sleep(0.2)

p, m, r_arr, nu, h1, k, w, x = tov(EOS, init_VEC, r_i, p_min,p_max, 
                           omega, nl, progress = True, l = l)

max_idx, m_R, r_R, p_R, ec_R, nu_R, h1_R, k_R, w_R, x_R, schild, \
interior = surface_conditions(p, m, r_arr, nu, h1, k, w, x)

print("== Second Integration == ")
print_params(p, m, r_arr, nu, h1, k, w, x)

# Update init_VEC
nu_ext = -lamba_metric(m_R, r_R)
nu_int = nu_R #At surface
delta_nu = nu_int - nu_ext
nu0 =  nu0 - delta_nu

init_VEC = [p_c, m0, nu0, H10, K0, W0, X0]
time.sleep(0.2)

p, m, r_arr, nu, h1, k, w, x = tov(EOS, init_VEC, r_i, p_min,p_max, 
                           omega, nl, progress = True, l = l)

max_idx, m_R, r_R, p_R, ec_R, nu_R, h1_R, k_R, w_R, x_R, schild, \
interior = surface_conditions(p, m, r_arr, nu, h1, k, w, x)

print("== Corrected Integration == ")
print_params(p, m, r_arr, nu, h1, k, w, x)
# Out:
# Initial:  [1.3453726909490657e+35, 4109534105318919.0, -1, 6.753259580326414e-13, -4.197570957432259e-14, 1, 1.140155775511068e+23]
# HBox(children=(FloatProgress(value=0.0, max=20000.0), HTML(value='')))
# == First Integration ==
# Star has mass 1.396 Msun and radius 11.464km
# Interior Surface: 0.58704551
# Exterior Surface: 0.64053412
# v0: -1
# Lamda: 0.44545288072390593
# Boundary Term: 5.042292848115186e+25
# HBox(children=(FloatProgress(value=0.0, max=20000.0), HTML(value='')))
# == Second Integration ==
# Star has mass 1.396 Msun and radius 11.464km
# Interior Surface: 0.64053436
# Exterior Surface: 0.64053408
# v0: -0.9127999465216896
# Lamda: 0.4454529487038856
# Boundary Term: 1.6678323731788663e+26
# HBox(children=(FloatProgress(value=0.0, max=20000.0), HTML(value='')))
# == Corrected Integration ==
# Star has mass 1.396 Msun and radius 11.464km
# Interior Surface: 0.64053408
# Exterior Surface: 0.64053408
# v0: -0.9128003871340661
# Lamda: 0.44545294824984377
# Boundary Term: 1.667825999801322e+26

# %%
# Delete when shifting over to python
old_backend = mpl.get_backend() 
# %matplotlib notebook 
# ====================================================================================
fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()
fig.show()
fig.canvas.draw()
plt.xlabel("K0")
plt.ylabel("log10 boundary value")

def optimize_x_R(K0):
    init_VEC = [p_c, m0, nu0, H10, K0, W0, X0]
    p, m, r_arr, nu, h1, k, w, x = tov(EOS, init_VEC, r_i, p_min,p_max, 
                                       omega, nl, progress = False, l = l, n_iter_max = 20000)
    max_idx, m_R, r_R, p_R, ec_R, nu_R, h1_R, k_R, w_R, x_R, schild, \
    interior = surface_conditions(p, m, r_arr, nu, h1, k, w, x)
    loss = np.log10(abs(x_R))
    ax.scatter(K0, loss, color = "goldenrod", marker = "+")
    fig.canvas.draw()
    return loss

K0_guess = K0
init_guess = [K0_guess]
res = minimize(optimize_x_R, x0 = init_guess, method='Nelder-Mead', 
               options = {"disp": True, "maxiter":20, "fatol": 1e-20})

mpl.use(old_backend) # Delete when shifting over to python
display(res)
print(f"K0: {res.x[0]:.4e}")
K0 = res.x[0]

# for K0 in np.linspace(-1e-11, 1e-11, 100):
#     optimize_x_R(K0)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/scipy/integrate/_ode.py:1011: UserWarning: vode: Excess work done on this call. (Perhaps wrong MF.)
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# Warning: Maximum number of iterations has been exceeded.
#  final_simplex: (array([[-9.28e-13],
#        [-9.28e-13]]), array([21.7 , 22.29]))
#            fun: 21.702990259339
#        message: 'Maximum number of iterations has been exceeded.'
#           nfev: 40
#            nit: 20
#         status: 2
#        success: False
#              x: array([-9.28e-13])
# K0: -9.2832e-13

# %%
init_VEC = [p_c, m0, nu0, H10, K0, W0, X0]
time.sleep(0.2)

p, m, r_arr, nu, h1, k, w, x = tov(EOS, init_VEC, r_i, p_min,p_max, 
                           omega, nl, progress = True, l = l)

max_idx, m_R, r_R, p_R, ec_R, nu_R, h1_R, k_R, w_R, x_R, schild, \
interior = surface_conditions(p, m, r_arr, nu, h1, k, w, x)

print("== Corrected Integration == ")
print_params(p, m, r_arr, nu, h1, k, w, x)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=20000.0), HTML(value='')))
# == Corrected Integration ==
# Star has mass 1.396 Msun and radius 11.464km
# Interior Surface: 0.64053387
# Exterior Surface: 0.64053385
# v0: -0.9128003871340661
# Lamda: 0.44545331204800914
# Boundary Term: 5.046499787932071e+21

# %%
# # Delete when shifting over to python
# old_backend = mpl.get_backend() 
# %matplotlib notebook 
# # ====================================================================================
# fig = plt.figure()
# ax = fig.add_subplot(111)
# plt.ion()
# fig.show()
# fig.canvas.draw()
# plt.xlabel("f-mode (Hz)")
# plt.ylabel("boundary value")

# def minimize_boundary_plot(params, p = p, EOS = EOS):
#     omega = params
#     p, m, r_arr, nu, h1, k, w, x = tov(EOS, init_VEC, r_i, p_min,p_max, 
#                                        omega, nl, progress = False, l = l, n_iter_max = 20000)
#     max_idx, m_R, r_R, p_R, ec_R, nu_R, h1_R, k_R, w_R, x_R, schild, \
#     interior = surface_conditions(p, m, r_arr, nu, h1, k, w, x)
#     loss = np.log10(abs(x_R))
#     ax.scatter(omega/(2*np.pi), loss, color = "dodgerblue", marker = "x")
#     fig.canvas.draw()
#     return loss

# omega_guess = (2*np.pi) * 2.4e3
# init_guess = [omega_guess]
# res = minimize(minimize_boundary_plot, x0 = init_guess, method='Nelder-Mead', 
#                options = {"disp": True, "maxiter":15})
# omg = res.x[0]
# omega = omg
# f = omg/(2*np.pi)
# mpl.use(old_backend) # Delete when shifting over to python
# display(res)
# print(f"fmode: {f:.2f} Hz")

# %%
# omega = omg
# init_VEC = [p_c, m0, nu0, H10, K0, W0, X0]
# time.sleep(0.2)

# p, m, r_arr, nu, h1, k, w, x = tov(EOS, init_VEC, r_i, p_min,p_max, 
#                            omega, nl, progress = True, l = l)

# max_idx, m_R, r_R, p_R, ec_R, nu_R, h1_R, k_R, w_R, x_R, schild, \
# interior = surface_conditions(p, m, r_arr, nu, h1, k, w, x)

# print("== Corrected Integration == ")
# print_params(p, m, r_arr, nu, h1, k, w, x)

# %%
# Zerilli equation helper functions
# Dimensions CHECKED
def g(r, m_R, nl):
    b = _b(r, m_R)
    n = nl
    num = n * (n+1) + 3*n*b + 6*(b**2)
    dem = (n + 3*b)
    return num/dem

# Dimensions CHECKED
def h(r, m_R, nl):
    b = _b(r, m_R)
    n = nl
    num = n - 3*n*b - 3*(b**2)
    dem = (1-2*b) * (n+3*b)
    return num/dem

# Dimensions CHECKED
def _k(r, m_R, nl):
    b = _b(r, m_R)
    n = nl
    return 1/(1-2*b)

# Dimensions UNCHECKED
def H0_zerilli(r, omega, m_R, nl, H1, K):
    b = _b(r, m_R)
    n = nl
    term1 = H1*(((omega*r)**2) - (n+1)*b)
    term2 = K*(n*(1-2*b)-((omega*r)**2)+b*(1-3*b))
    num = term1 + term2
    dem = (1-2*b)*(3*b+n)
    return num/dem

# %%
from scipy.integrate import odeint
def V_z(r, m_R, nl):
    b = _b(r, m_R)
    n = nl
    fac = (1-2*b)
    num = 2*(n**2)*(n+1) + 6*(n**2)*b + 18*n*(b**2) + 18*(b**3)
    dem = (r**2) * (n+3*b)**2
    return fac * num/dem

def r_star_func(r, m_R):
    return r + 2 * (G/(c**2)) * m_R * np.log(abs((r*(c**2))/(2*G*m_R) - 1))

def zerilli(u, r_star, omega):
    z, dZdr_star = u
#     c_star = r_star_func(c, m_R)
    c_star = 1
    d2Zdr2_star = z * (V_z(r_star, m_R, nl) - omega*np.conj(omega)/(c_star**2))
    ret = [dZdr_star, d2Zdr2_star] # dZ/dr*, d2Z/dr*2
    return ret

# %%
K_R = k_R
num = h1_R - _k(r_R, m_R, nl) * K_R
dem = (h(r_R, m_R, nl) - _k(r_R, m_R, nl) * g(r_R, m_R, nl))
z_R = r_R*num/dem
dzdR_R = (K_R - g(r_R, m_R, nl)*z_R/r_R)
z0 = [z_R, dzdR_R] 
print(z0)
print(m_R, r_R)
# Out:
# [-3.388415573648838e-07, 9.944981535564537e-13]
# 2.775310176896487e+33 1146401.0

# %%
omega = 2e3*2*np.pi
init_VEC = [p_c, m0, nu0, H10, K0, W0, X0]
time.sleep(0.2)

p, m, r_arr, nu, h1, k, w, x = tov(EOS, init_VEC, r_i, p_min,p_max, 
                           omega, nl, progress = True, l = l)

max_idx, m_R, r_R, p_R, ec_R, nu_R, h1_R, k_R, w_R, x_R, schild, \
interior = surface_conditions(p, m, r_arr, nu, h1, k, w, x)

z0 = [-0.004, -0.004] 

# From surface to inf
r_vals = np.linspace(r_R, 25 * c / omega, 20000)
r_star_vals = r_star_func(r_vals, m_R)
sol = odeint(zerilli, y0 = z0, t = r_star_vals, args = (omega,))
z, dzdr_star = sol.T

plt.figure()
# plt.scatter(r_R/km2cm, z_R, color = "red", label = "TOV")
plt.plot(r_star_vals/km2cm, z)
plt.xlabel("r* (km)")
plt.ylabel("Z")
plt.show()

plt.figure()
# plt.scatter(r_R/km2cm, dzdR_R, color = "red", label = "TOV")
plt.plot(r_star_vals/km2cm, dzdr_star)
plt.xlabel("r* (km)")
plt.ylabel("dZdr")
plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=20000.0), HTML(value='')))
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)

# %%
plt.plot(r_star_vals, V_z(r_star_vals, m_R, nl))
plt.show()

# %%
# omega = 2e3*2*np.pi

# K_R = k_R
# num = h1_R - _k(r_R, m_R, nl) * K_R
# dem = (h(r_R, m_R, nl) - _k(r_R, m_R, nl) * g(r_R, m_R, nl))
# z_R = r_R*num/dem
# dzdR_R = (K_R - g(r_R, m_R, nl)*z_R/r_R)
# z0 = [z_R, dzdR_R] 

# # From surface to inf
# r_vals = np.linspace(r_R, c * 25 / omega, 20000)
# r_star_vals = r_star(r_vals, m_R)
# sol = odeint(zerilli, y0 = z0, t = r_star_vals, args = (omega,))
# z, dzdr_star = sol.T

# plt.figure()
# plt.scatter(r_star(r_R, m_R)/km2cm, z_R, color = "red", label = "TOV")
# plt.plot(r_star_vals/km2cm, z)
# plt.xlabel("r* (km)")
# plt.ylabel("Z")
# plt.legend(frameon = False)
# plt.show()

# plt.figure()
# plt.scatter(r_star(r_R, m_R)/km2cm, dzdR_R, color = "red", label = "TOV")
# plt.plot(r_star_vals/km2cm, dzdr_star)
# plt.xlabel("r* (km)")
# plt.ylabel("dZdr")
# plt.legend(frameon = False)
# plt.show()

# %%
# def alphas(omega, nl, m_R):
#     n = nl
#     alpha0 = 1 + 1j
#     alpha1 = -1j*(n+1)*alpha0*c/omega
#     alpha2 = alpha0 * (c**2)*(-n*(n+1)+1j*m_R*omega*(G/(c**2))*(3/2 + 3/n))/(2*omega**2)
#     return n, alpha0, alpha1, alpha2

# # Dimensions CHECKED
# def Z_minus_func(r, r_star, nl, m_R, omega):  
#     n, alpha0, alpha1, alpha2 = alphas(omega, nl, m_R)
#     brackets = alpha0 + alpha1/r + alpha2/(r**2)
#     return np.exp(-1j*omega*r_star) * brackets

# # Dimensions CHECKED
# def Z_plus_func(r, r_star, nl, omega):
#     n, alpha0, alpha1, alpha2 = alphas(omega, nl, m_R)
#     Z_minus = Z_minus_func(r, r_star, nl, m_R, omega)
#     return np.conjugate(Z_minus)

# # Dimensions CHECKED
# def dZ_dr_minus_func(r, r_star, nl, m_R, omega):
#     b = _b(r, m_R) 
    
#     n, alpha0, alpha1, alpha2 = alphas(omega, nl, m_R)
    
#     num = alpha2 + 1j*alpha1*(1-2*b)*c/omega
#     dem = r**2
#     brackets = alpha0 + alpha1/r + num/dem
#     return -1j*omega/c*np.exp(-1j*omega*r_star) * brackets

# # Dimensions CHECKED
# def dZ_dr_plus_func(r, r_star, nl, m_R, omega):
#     dZ_dr_minus = dZ_dr_minus_func(r, r_star, nl, m_R, omega)
#     return np.conjugate(dZ_dr_minus)

# # Delete when shifting over to python
# old_backend = mpl.get_backend() 
# %matplotlib notebook 
# # ====================================================================================
# fig = plt.figure()
# ax = fig.add_subplot(111)
# plt.ion()
# fig.show()
# fig.canvas.draw()
# plt.xlabel("f-mode (Hz)")
# plt.ylabel("log boundary value")

# K_R = k_R
# num = h1_R - _k(r_R, m_R, nl) * K_R
# dem = (h(r_R, m_R, nl) - _k(r_R, m_R, nl) * g(r_R, m_R, nl))
# z_R = r_R*num/dem
# dzdR_R = (K_R - g(r_R, m_R, nl)*z_R/r_R)

# # From surface to inf
# r_vals = np.linspace(r_R, c * 25 / omega, 20000)
# r_star_vals = r_star(r_vals, m_R)
# z0 = [z_R, dzdR_R] 
    
# def optimize_fmode_plot(omega): 
#     sol = odeint(zerilli, y0 = z0, t = r_star_vals, args = (omega,))

#     z, dzdr_star = sol.T

#     # Incoming and Outgoing
#     dZdr_star = dzdr_star
#     dZdr_minus = dZ_dr_minus_func(r_vals, r_star_vals, nl, m_R, omega)
#     dZdr_plus = dZ_dr_plus_func(r_vals, r_star_vals, nl, m_R, omega)
#     Z = z 
#     Z_minus = Z_minus_func(r_vals, r_star_vals, nl, m_R, omega)
#     Z_plus = Z_plus_func(r_vals, r_star_vals, nl, omega)

#     num = dZdr_star * Z_minus - dZdr_minus * Z
#     dem = dZdr_plus - dZdr_minus * Z_plus
#     A_plus = num/dem
#     A_minus = (Z - Z_plus*A_plus)/(Z_minus)
#     loss = np.log10(min(np.abs(A_plus)))
#     ax.scatter(omega/(2*np.pi), loss, color = "forestgreen", marker = "x")
#     fig.canvas.draw()
#     return loss

# omega_guess = 2.9e3*2*np.pi
# init_guess = [omega_guess]
# res = minimize(optimize_fmode_plot, x0 = init_guess, method='Nelder-Mead', 
#                options = {"disp": True, "maxiter":15})
# f = res.x[0]/(2*np.pi)
# mpl.use(old_backend) # Delete when shifting over to python
# display(res)
# print(f"fmode: {f:.2f} Hz")

# %%
# # Best guess
# omega = res.x[0]

# K_R = k_R
# num = h1_R - _k(r_R, m_R, nl) * K_R
# dem = (h(r_R, m_R, nl)/r_R - _k(r_R, m_R, nl) * g(r_R, m_R, nl)/r_R)
# z_R = num/dem
# dzdR_R = (K_R - g(r_R, m_R, nl)*z_R/r_R)

# # From surface to inf
# r_vals = np.linspace(r_R, c * 25 / omega, 20000)
# r_star_vals = r_star(r_vals, m_R)
# z0 = [z_R, dzdR_R] 

# sol = odeint(zerilli, y0 = z0, t = r_star_vals, args = (omega,))

# z, dzdr_star = sol.T

# # Incoming and Outgoing
# dZdr_star = dzdr_star
# dZdr_minus = dZ_dr_minus_func(r_vals, r_star_vals, nl, m_R, omega)
# dZdr_plus = dZ_dr_plus_func(r_vals, r_star_vals, nl, m_R, omega)
# Z = z 
# Z_minus = Z_minus_func(r_vals, r_star_vals, nl, m_R, omega)
# Z_plus = Z_plus_func(r_vals, r_star_vals, nl, omega)

# num = dZdr_star * Z_minus - dZdr_minus * Z
# dem = dZdr_plus - dZdr_minus * Z_plus
# A_plus = num/dem
# A_minus = (Z - Z_plus*A_plus)/(Z_minus)
# loss = min(np.abs(A_plus))
# print(loss)

# %%
# plt.figure()
# plt.scatter(r_star(r_R, m_R)/km2cm, z_R, color = "red", label = "TOV")
# plt.plot(r_star_vals/km2cm, z)
# plt.xlabel("r* (km)")
# plt.ylabel("Z")
# plt.legend(frameon = False)
# plt.show()

# plt.figure()
# plt.scatter(r_R/km2cm, dzdR_R, color = "red", label = "TOV")
# plt.plot(r_vals/km2cm, dzdr_star)
# plt.xlabel("r* (km)")
# plt.ylabel("dZdr")
# plt.legend(frameon = False)
# plt.show()

# %%
# # zero_crossings = np.where(np.diff(np.sign(np.real(A_plus))))[0]
# # fmodes = (1/omega_vals[zero_crossings])/(2*np.pi)
# # fmodes

# plt.figure()
# cols = r_star_vals/km2cm
# sc = plt.scatter(np.real(A_plus), np.imag(A_plus), c=cols, cmap = cm.rainbow, s = 5)
# plt.scatter(0, 0)
# plt.xlabel("Real[A+]")
# plt.ylabel("Im[A+]")
# plt.colorbar(sc, label = r"$r*$")
# plt.axhline(0)
# plt.axvline(0)
# plt.tight_layout()
# lim = 1e-17
# plt.xlim(-lim, lim)
# plt.ylim(-lim, lim)
# plt.show()

# %%
# plt.figure()
# cols = r_star_vals/km2cm
# sc = plt.scatter(np.real(A_minus), np.imag(A_minus), c=cols, cmap = cm.rainbow, s = 5)
# plt.scatter(0, 0)
# plt.xlabel("Real[A+]")
# plt.ylabel("Im[A+]")
# plt.colorbar(sc, label = r"$r*$")
# plt.axhline(0)
# plt.axvline(0)
# plt.tight_layout()
# lim = 1e-17
# plt.show()

# %%
# vec = np.abs(A_plus)

# from scipy.signal import find_peaks
# plt.figure()
# plt.plot(r_star_vals/km2cm, np.abs(A_plus), label = "+")
# plt.plot(r_star_vals/km2cm, np.abs(A_minus), label = "-")
# plt.xlabel(r"r* (km)")
# plt.ylabel("Amplitude")
# plt.legend()
# plt.show()
