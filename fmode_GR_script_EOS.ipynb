# %%
# %%capture
# %run general_relativity/fModes.py

# %%
fmodes1 = fmodes()
fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/LCEHL_EOS_posterior_samples/eos_1000.csv')
fmodes1.parallel_simulation(progress = True)
fmodes1.print_results()
fmodes1.plot_fmass()
fmodes1.plot_mass_radius()
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 289.30it/s]
# M_max = (1.9603524042432618+0j)
# R_max = (9.76701+0j)
# f_max = (2893.134431613627+0j)
#
# M_1.4 = (1.6495238004052424+0j)
# R_1.4 = (12.847010000000001+0j)
# f_1.4 = (1793.8304416244382+0j)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/_asarray.py:136: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_axes.py:5274: ComplexWarning: Casting complex values to real discards the imaginary part
#   pts[0] = start
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_axes.py:5275: ComplexWarning: Casting complex values to real discards the imaginary part
#   pts[N + 1] = end
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_axes.py:5277: ComplexWarning: Casting complex values to real discards the imaginary part
#   pts[1:N+1, 0] = indslice
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_axes.py:5278: ComplexWarning: Casting complex values to real discards the imaginary part
#   pts[1:N+1, 1] = dep1slice
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_axes.py:5279: ComplexWarning: Casting complex values to real discards the imaginary part
#   pts[N+2:, 0] = indslice[::-1]
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_axes.py:5280: ComplexWarning: Casting complex values to real discards the imaginary part
#   pts[N+2:, 1] = dep2slice[::-1]
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
# fmodes1 = fmodes()
# fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/2205.02081/SLY4.csv')
# fmodes1.parallel_simulation()
# fmodes1.print_results()
# fmodes1.plot_fmass()
# fmodes1.plot_mass_radius()

# %%
# fmodes1 = fmodes()
# fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/2205.02081/NL3.csv')
# fmodes1.parallel_simulation()
# fmodes1.print_results()
# fmodes1.plot_fmass()
# fmodes1.plot_mass_radius()

# %%
# fmodes1 = fmodes()
# fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/eos_data/sly230a.csv')
# fmodes1.parallel_simulation()
# fmodes1.print_results()
# fmodes1.plot_fmass()
# fmodes1.plot_mass_radius()

# %%
# fmodes1 = fmodes()
# fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/eos_data/sly.csv')
# fmodes1.parallel_simulation()
# fmodes1.print_results()
# fmodes1.plot_fmass()
# fmodes1.plot_mass_radius()

# %%
# fmodes1 = fmodes()
# fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/eos_data/nl3cr.csv')
# fmodes1.parallel_simulation()
# fmodes1.print_results()
# fmodes1.plot_fmass()
# fmodes1.plot_mass_radius()

# %%
# fmodes1 = fmodes()
# fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/eos1.csv')
# fmodes1.parallel_simulation()
# fmodes1.print_results()
# fmodes1.plot_fmass()
# fmodes1.plot_mass_radius()
