# %%
# %%capture
# %run cowling_approximation/fModes.py

# %%
fmodes1 = fmodes()
fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/2205.02081/SLY230A.csv')
fmodes1.parallel_simulation()
fmodes1.print_results()
fmodes1.plot_fmass()
fmodes1.plot_mass_radius()
# Out:
# 100%|██████████| 40/40 [01:13<00:00,  1.85s/it]
# M_max = 2.098173387297502
# R_max = 10.35201
# f_max = 2800.861635541689
#
# M_1.4 = 1.3882172612729082
# R_1.4 = 11.81801
# f_1.4 = 2367.3359743458595

# %%
fmodes1 = fmodes()
fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/2205.02081/SLY4.csv')
fmodes1.parallel_simulation()
fmodes1.print_results()
fmodes1.plot_fmass()
fmodes1.plot_mass_radius()
# Out:
# 100%|██████████| 40/40 [01:12<00:00,  1.81s/it]
# M_max = 2.050060979565951
# R_max = 10.08001
# f_max = 2878.7450236968607
#
# M_1.4 = 1.3782592095756903
# R_1.4 = 11.69901
# f_1.4 = 2396.7612205666624

# %%
fmodes1 = fmodes()
fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/2205.02081/NL3.csv')
fmodes1.parallel_simulation()
fmodes1.print_results()
fmodes1.plot_fmass()
fmodes1.plot_mass_radius()
# Out:
# 100%|██████████| 30/30 [00:49<00:00,  1.64s/it]
# M_max = 2.7751082493564323
# R_max = 13.17101
# f_max = 2151.781031065073
#
# M_1.4 = 1.2840398739892753
# R_1.4 = 13.82501
# f_1.4 = 1758.2698649477074

# %%
fmodes1 = fmodes()
fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/eos_data/sly230a.csv')
fmodes1.parallel_simulation()
fmodes1.print_results()
fmodes1.plot_fmass()
fmodes1.plot_mass_radius()
# Out:
# 100%|██████████| 60/60 [01:28<00:00,  1.47s/it]
# M_max = 2.099199308028494
# R_max = 10.18901
# f_max = 2829.5769999273402
#
# M_1.4 = 1.3598189078988594
# R_1.4 = 11.84901
# f_1.4 = 2323.6568512041104

# %%
fmodes1 = fmodes()
fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/eos_data/sly.csv')
fmodes1.parallel_simulation()
fmodes1.print_results()
fmodes1.plot_fmass()
fmodes1.plot_mass_radius()
# Out:
# 100%|██████████| 34/34 [01:42<00:00,  3.01s/it]
# M_max = 2.049657535224178
# R_max = 10.00701
# f_max = 2435.7812060766178
#
# M_1.4 = 1.4317755357390758
# R_1.4 = 11.69901
# f_1.4 = 2398.675234594827

# %%
fmodes1 = fmodes()
fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/eos_data/nl3cr.csv')
fmodes1.parallel_simulation()
fmodes1.print_results()
fmodes1.plot_fmass()
fmodes1.plot_mass_radius()
# Out:
# 100%|██████████| 57/57 [01:33<00:00,  1.65s/it]
# M_max = 2.7752101778111764
# R_max = 13.39901
# f_max = 2054.4218000218643
#
# M_1.4 = 1.4698819174694024
# R_1.4 = 14.91601
# f_1.4 = 1899.0793837248602
