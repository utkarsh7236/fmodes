# %%
# %%capture
# %run cowling_approximation/fModes.py

# %%
fmodes = fmodes()
fmodes.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/2205.02081/SLY230A.csv')
fmodes.parallel_simulation()
fmodes.print_results()
fmodes.plot_fmass()
fmodes.plot_mass_radius()
# Out:
# 100%|██████████| 40/40 [00:59<00:00,  1.49s/it]
# M_max = 2.098173387297502
# R_max = 10.35201
# f_max = 2800.861635541689
#
# M_1.4 = 1.3882172612729082
# R_1.4 = 11.81801
# f_1.4 = 2367.3359743458595

# %%
fmodes.plot_fmode_linear()
