# %%
# %%capture
# %run cowling_approximation/fModes.py

# %%
fmodes1 = fmodes()
fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/2205.02081/SLY230A.csv')
fmodes1.parallel_simulation()
fmodes1.print_results()
fmodes1.plot_fmass()
fmodes1.plot_mass_radius()
# Out:
# 100%|██████████| 40/40 [00:58<00:00,  1.46s/it]
# M_max = 2.0981723945441533
# R_max = 10.27801
# f_max = 2800.8713199915887
#
# M_1.4 = 1.3882136652209258
# R_1.4 = 11.58401
# f_1.4 = 2367.359525988132

# %%
fmodes1 = fmodes()
fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/2205.02081/SLY4.csv')
fmodes1.parallel_simulation()
fmodes1.print_results()
fmodes1.plot_fmass()
fmodes1.plot_mass_radius()
# Out:
# 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# M_max = 2.0500599019186088
# R_max = 10.00801
# f_max = 2878.7686490578344
#
# M_1.4 = 1.3782557001493279
# R_1.4 = 11.46901
# f_1.4 = 2396.7673449758

# %%
fmodes1 = fmodes()
fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/2205.02081/NL3.csv')
fmodes1.parallel_simulation()
fmodes1.print_results()
fmodes1.plot_fmass()
fmodes1.plot_mass_radius()
# Out:
# 100%|██████████| 30/30 [03:20<00:00,  6.69s/it]
# M_max = 2.7751073519329523
# R_max = 13.17201
# f_max = 2151.7803982868763
#
# M_1.4 = 1.2840389406550952
# R_1.4 = 13.82501
# f_1.4 = 1758.2539439671866

# %%
fmodes1 = fmodes()
fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/eos_data/sly230a.csv')
fmodes1.parallel_simulation()
fmodes1.print_results()
fmodes1.plot_fmass()
fmodes1.plot_mass_radius()
# Out:
# 100%|██████████| 60/60 [01:25<00:00,  1.42s/it]
# M_max = 2.0991983631448563
# R_max = 10.11001
# f_max = 2839.4729619999493
#
# M_1.4 = 1.3598148352899484
# R_1.4 = 11.57501
# f_1.4 = 2362.396057322536

# %%
fmodes1 = fmodes()
fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/eos_data/sly.csv')
fmodes1.parallel_simulation()
fmodes1.print_results()
fmodes1.plot_fmass()
fmodes1.plot_mass_radius()
# Out:
# 100%|██████████| 34/34 [00:23<00:00,  1.43it/s]
# M_max = 2.0496562954756423
# R_max = 9.92701
# f_max = 2902.268653870822
#
# M_1.4 = 1.4317714675654984
# R_1.4 = 11.44801
# f_1.4 = 2430.9461807752996

# %%
fmodes1 = fmodes()
fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/eos_data/nl3cr.csv')
fmodes1.parallel_simulation()
fmodes1.print_results()
fmodes1.plot_fmass()
fmodes1.plot_mass_radius()
# Out:
# 100%|██████████| 57/57 [01:17<00:00,  1.37s/it]
# M_max = 2.775207479753348
# R_max = 13.29001
# f_max = 3224.2032776448564
#
# M_1.4 = 1.4698690503507172
# R_1.4 = 14.46101
# f_1.4 = 1809.3213472094442

# %%
fmodes1 = fmodes()
fmodes1.set_EOS('/Users/utkarsh/PycharmProjects/fmodes/eos1.csv')
fmodes1.parallel_simulation()
fmodes1.print_results()
fmodes1.plot_fmass()
fmodes1.plot_mass_radius()
# Out:
# 100%|██████████| 44/44 [00:48<00:00,  1.10s/it]
# M_max = 2.14134111830973
# R_max = 12.03301
# f_max = 2380.497568885443
#
# M_1.4 = 1.359090259460538
# R_1.4 = 11.95701
# f_1.4 = 2223.10046896261
